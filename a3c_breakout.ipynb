# %% [markdown]
# <a href="https://colab.research.google.com/github/Arem77/Colab/blob/master/a3c_breakout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import random
import threading
import time

import numpy as np
import tensorflow as tf
import gym

# from collections import deque
from skimage.color import rgb2gray
from skimage.transform import resize
from keras.layers import Dense, Flatten, Input, Conv2D
from keras.optimizers import RMSprop
from keras.models import Model
from keras import backend as K
import tensorflow as tf

from tensorboardcolab import *

from gym import envs
# Out:
# Using TensorFlow backend.

# %%
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# Suggested packages:
#   libgle3
# The following NEW packages will be installed:
#   python-opengl
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 496 kB of archives.
# After this operation, 5,416 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-opengl all 3.1.0+dfsg-1 [496 kB]
# Fetched 496 kB in 0s (4,583 kB/s)
# Selecting previously unselected package python-opengl.
# (Reading database ... 144487 files and directories currently installed.)
# Preparing to unpack .../python-opengl_3.1.0+dfsg-1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-1) ...
# Setting up python-opengl (3.1.0+dfsg-1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   xvfb
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 784 kB of archives.
# After this operation, 2,266 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.4 [784 kB]
# Fetched 784 kB in 0s (4,572 kB/s)
# Selecting previously unselected package xvfb.
# (Reading database ... 146842 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.4_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.4) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.4) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Collecting pyvirtualdisplay
#   Downloading https://files.pythonhosted.org/packages/d0/8a/643043cc70791367bee2d19eb20e00ed1a246ac48e5dbe57bbbcc8be40a9/PyVirtualDisplay-1.3.2-py2.py3-none-any.whl
# Collecting EasyProcess
#   Downloading https://files.pythonhosted.org/packages/48/3c/75573613641c90c6d094059ac28adb748560d99bd27ee6f80cce398f404e/EasyProcess-0.3-py2.py3-none-any.whl
# Installing collected packages: EasyProcess, pyvirtualdisplay
# Successfully installed EasyProcess-0.3 pyvirtualdisplay-1.3.2

# %%
# 멀티쓰레딩을 위한 글로벌 변수
global episode
episode = 0
EPISODES = 8000000
# 환경 생성
env_name = "BreakoutDeterministic-v4"
GAME = "Breakout-v4"

# %%
import shutil
from datetime import datetime

base_path = '/content'

datetime_path = datetime.now().strftime('%Y-%m-%d_%H:%M:%S')

model_path = os.path.join(base_path, 'save_model', datetime_path)

os.makedirs(model_path, exist_ok=True)

# %%
class A3CAgent:
    def __init__(self, action_size):
        # 상태크기와 행동크기를 갖고옴
        self.state_size = (84, 84, 4)
        self.action_size = action_size
        # A3C 하이퍼파라미터
        self.discount_factor = 0.99
        self.no_op_steps = 30
        self.actor_lr = 2.5e-4
        self.critic_lr = 2.5e-4
        # 쓰레드의 갯수
        self.threads = 8

        # 정책신경망과 가치신경망을 생성
        self.actor, self.critic = self.build_model()
        # 정책신경망과 가치신경망을 업데이트하는 함수 생성
        self.optimizer = [self.actor_optimizer(), self.critic_optimizer()]

        # 텐서보드 설정
        self.sess = tf.InteractiveSession()
        K.set_session(self.sess)
        self.sess.run(tf.global_variables_initializer())

        self.summary_placeholders, self.update_ops, self.summary_op = \
            self.setup_summary()
        # self.summary_writer = \
        #     tf.summary.FileWriter('summary/breakout_a3c', self.sess.graph)

        tbc=TensorBoardColab()
        
        self.summary_writer = tbc.get_writer()
        self.summary_writer = tf.summary.FileWriter(
            './Graph', self.sess.graph)
        self.sess.run(tf.global_variables_initializer())

    # 쓰레드를 만들어 학습을 하는 함수
    def train(self):
        # 쓰레드 수만큼 Agent 클래스 생성
        agents = [Agent(self.action_size, self.state_size,
                        [self.actor, self.critic], self.sess,
                        self.optimizer, self.discount_factor,
                        [self.summary_op, self.summary_placeholders,
                         self.update_ops, self.summary_writer])
                  for _ in range(self.threads)]

        # 각 쓰레드 시작
        for agent in agents:
            time.sleep(1)
            agent.start()

        # 10분(600초)에 한번씩 모델을 저장
        while True:
            time.sleep(60 * 10)
            # self.save_model("./save_model/breakout_a3c")
            self.save_model(os.path.join(model_path, "breakout_a3c"))

    # 정책신경망과 가치신경망을 생성
    def build_model(self):
        input = Input(shape=self.state_size)
        conv = Conv2D(16, (8, 8), strides=(4, 4), activation='relu')(input)
        conv = Conv2D(32, (4, 4), strides=(2, 2), activation='relu')(conv)
        conv = Flatten()(conv)
        fc = Dense(256, activation='relu')(conv)

        policy = Dense(self.action_size, activation='softmax')(fc)
        value = Dense(1, activation='linear')(fc)

        actor = Model(inputs=input, outputs=policy)
        critic = Model(inputs=input, outputs=value)

        # 가치와 정책을 예측하는 함수를 만들어냄
        actor._make_predict_function()
        critic._make_predict_function()

        actor.summary()
        critic.summary()

        return actor, critic

    # 정책신경망을 업데이트하는 함수
    def actor_optimizer(self):
        action = K.placeholder(shape=[None, self.action_size])
        advantages = K.placeholder(shape=[None, ])

        policy = self.actor.output

        # 정책 크로스 엔트로피 오류함수
        action_prob = K.sum(action * policy, axis=1)
        cross_entropy = K.log(action_prob + 1e-10) * advantages
        cross_entropy = -K.sum(cross_entropy)

        # 탐색을 지속적으로 하기 위한 엔트로피 오류
        entropy = K.sum(policy * K.log(policy + 1e-10), axis=1)
        entropy = K.sum(entropy)

        # 두 오류함수를 더해 최종 오류함수를 만듬
        loss = cross_entropy + 0.01 * entropy

        optimizer = RMSprop(lr=self.actor_lr, rho=0.99, epsilon=0.01)
        updates = optimizer.get_updates(loss, self.actor.trainable_weights)
        train = K.function([self.actor.input, action, advantages],
                           [loss], updates=updates)
        return train

    # 가치신경망을 업데이트하는 함수
    def critic_optimizer(self):
        discounted_prediction = K.placeholder(shape=(None,))

        value = self.critic.output

        # [반환값 - 가치]의 제곱을 오류함수로 함
        loss = K.mean(K.square(discounted_prediction - value))

        optimizer = RMSprop(lr=self.critic_lr, rho=0.99, epsilon=0.01)
        updates = optimizer.get_updates(loss, self.critic.trainable_weights)
        train = K.function([self.critic.input, discounted_prediction],
                           [loss], updates=updates)
        return train

    def load_model(self, name):
        self.actor.load_weights(name + "_actor.h5")
        self.critic.load_weights(name + "_critic.h5")

    def save_model(self, name):
        self.actor.save_weights(name + "_actor.h5")
        self.critic.save_weights(name + "_critic.h5")

    # 각 에피소드 당 학습 정보를 기록
    def setup_summary(self):
        episode_total_reward = tf.Variable(0.)
        episode_avg_max_q = tf.Variable(0.)
        episode_duration = tf.Variable(0.)

        tf.summary.scalar('Total Reward/Episode', episode_total_reward)
        tf.summary.scalar('Average Max Prob/Episode', episode_avg_max_q)
        tf.summary.scalar('Duration/Episode', episode_duration)

        summary_vars = [episode_total_reward,
                        episode_avg_max_q,
                        episode_duration]

        summary_placeholders = [tf.placeholder(tf.float32)
                                for _ in range(len(summary_vars))]
        update_ops = [summary_vars[i].assign(summary_placeholders[i])
                      for i in range(len(summary_vars))]
        summary_op = tf.summary.merge_all()
        return summary_placeholders, update_ops, summary_op

# %% [markdown]
# ### 액터러너의 run 함수의 순서
# 1. 액터러너의 로컬신경망에 따라 행동을 선택
# 2. 환경으로부터 다음 상태와 보상을 받음
# 3. 샘플을 저장
# 4. 에이전트가 목숨을 잃거나 t_max 타임스텝 동안 반복
# 5. 지정한 샘플로 글로벌신경망으로 보냄(optimizer)
# 6. 글로벌신경망은 로컬신경망으로부터 받은 샘플로 자신을 업데이트
# 7. 업데이트 된 글로벌신경망으로 엑터러너를 업데이트

# %%
# 액터러너 클래스(쓰레드)
class Agent(threading.Thread):
    def __init__(self, action_size, state_size, model, sess,
                 optimizer, discount_factor, summary_ops):
        threading.Thread.__init__(self)

        # A3CAgent 클래스에서 상속
        self.action_size = action_size
        self.state_size = state_size
        self.actor, self.critic = model
        self.sess = sess
        self.optimizer = optimizer
        self.discount_factor = discount_factor
        [self.summary_op, self.summary_placeholders,
         self.update_ops, self.summary_writer] = summary_ops

        # 지정된 타임스텝동안 샘플을 저장할 리스트
        self.states, self.actions, self.rewards = [], [], []

        # 로컬 모델 생성
        self.local_actor, self.local_critic = self.build_local_model()

        self.avg_p_max = 0
        self.avg_loss = 0

        # 모델 업데이트 주기
        self.t_max = 20
        self.t = 0

    def run(self):
        global episode
        env = gym.make(env_name)

        step = 0

        while episode < EPISODES:
            done = False
            dead = False

            score, start_life = 0, 5
            observe = env.reset()
            next_observe = observe

            # 0~30 상태동안 정지
            for _ in range(random.randint(1, 30)):
                observe = next_observe
                next_observe, _, _, _ = env.step(1)

            state = pre_processing(next_observe, observe)
            history = np.stack((state, state, state, state), axis=2)
            history = np.reshape([history], (1, 84, 84, 4))

            while not done:
                step += 1
                self.t += 1
                observe = next_observe
                action, policy = self.get_action(history)

                # 1: 정지, 2: 왼쪽, 3: 오른쪽
                if action == 0:
                    real_action = 1
                elif action == 1:
                    real_action = 2
                else:
                    real_action = 3

                # 죽었을 때 시작하기 위해 발사 행동을 함
                if dead:
                    action = 0
                    real_action = 1
                    dead = False

                # 선택한 행동으로 한 스텝을 실행
                next_observe, reward, done, info = env.step(real_action)

                # 각 타임스텝마다 상태 전처리
                next_state = pre_processing(next_observe, observe)
                next_state = np.reshape([next_state], (1, 84, 84, 1))
                next_history = np.append(next_state, history[:, :, :, :3],
                                         axis=3)

                # 정책의 최대값
                self.avg_p_max += np.amax(self.actor.predict(
                    np.float32(history / 255.)))

                if start_life > info['ale.lives']:
                    dead = True
                    start_life = info['ale.lives']

                score += reward
                reward = np.clip(reward, -1., 1.)

                # 샘플을 저장
                self.append_sample(history, action, reward)

                if dead:
                    history = np.stack((next_state, next_state,
                                        next_state, next_state), axis=2)
                    history = np.reshape([history], (1, 84, 84, 4))
                else:
                    history = next_history

                # 에피소드가 끝나거나 최대 타임스텝 수에 도달하면 학습을 진행
                if self.t >= self.t_max or done:
                    self.train_model(done)
                    self.update_local_model()
                    self.t = 0

                if done:
                    # 각 에피소드 당 학습 정보를 기록
                    episode += 1
                    print("episode:", episode, "  score:", score, "  step:",
                          step)

                    stats = [score, self.avg_p_max / float(step),
                             step]
                    for i in range(len(stats)):
                        self.sess.run(self.update_ops[i], feed_dict={
                            self.summary_placeholders[i]: float(stats[i])
                        })
                    summary_str = self.sess.run(self.summary_op)
                    self.summary_writer.add_summary(summary_str, episode + 1)
                    self.avg_p_max = 0
                    self.avg_loss = 0
                    step = 0

    # k-스텝 prediction 계산
    def discounted_prediction(self, rewards, done):
        discounted_prediction = np.zeros_like(rewards)
        running_add = 0

        if not done:
            running_add = self.local_critic.predict(np.float32(
                self.states[-1] / 255.))[0]

        for t in reversed(range(0, len(rewards))):
            running_add = running_add * self.discount_factor + rewards[t]
            discounted_prediction[t] = running_add
        return discounted_prediction

    # 정책신경망과 가치신경망을 업데이트
    def train_model(self, done):
        discounted_prediction = self.discounted_prediction(self.rewards, done)

        states = np.zeros((len(self.states), 84, 84, 4))
        for i in range(len(self.states)):
            states[i] = self.states[i]

        states = np.float32(states / 255.)

        values = self.local_critic.predict(states)
        values = np.reshape(values, len(values))

        advantages = discounted_prediction - values

        self.optimizer[0]([states, self.actions, advantages])
        self.optimizer[1]([states, discounted_prediction])
        self.states, self.actions, self.rewards = [], [], []

    # 로컬신경망을 생성하는 함수
    def build_local_model(self):
        input = Input(shape=self.state_size)
        conv = Conv2D(16, (8, 8), strides=(4, 4), activation='relu')(input)
        conv = Conv2D(32, (4, 4), strides=(2, 2), activation='relu')(conv)
        conv = Flatten()(conv)
        fc = Dense(256, activation='relu')(conv)
        policy = Dense(self.action_size, activation='softmax')(fc)
        value = Dense(1, activation='linear')(fc)

        local_actor = Model(inputs=input, outputs=policy)
        local_critic = Model(inputs=input, outputs=value)

        local_actor._make_predict_function()
        local_critic._make_predict_function()

        local_actor.set_weights(self.actor.get_weights())
        local_critic.set_weights(self.critic.get_weights())

        local_actor.summary()
        local_critic.summary()

        return local_actor, local_critic

    # 로컬신경망을 글로벌신경망으로 업데이트
    def update_local_model(self):
        self.local_actor.set_weights(self.actor.get_weights())
        self.local_critic.set_weights(self.critic.get_weights())

    # 정책신경망의 출력을 받아서 확률적으로 행동을 선택
    def get_action(self, history):
        history = np.float32(history / 255.)
        policy = self.local_actor.predict(history)[0]
        action_index = np.random.choice(self.action_size, 1, p=policy)[0]
        return action_index, policy

    # 샘플을 저장
    def append_sample(self, history, action, reward):
        self.states.append(history)
        act = np.zeros(self.action_size)
        act[action] = 1
        self.actions.append(act)
        self.rewards.append(reward)

# %% [markdown]
# ### 학습 속도를 높이기 위해 흑백 화면으로 전처리

# %%
# 학습속도를 높이기 위해 흑백화면으로 전처리
def pre_processing(next_observe, observe):
    processed_observe = np.maximum(next_observe, observe)
    processed_observe = np.uint8(
        resize(rgb2gray(processed_observe), (84, 84), mode='constant') * 255)
    return processed_observe

# %%
if __name__ == "__main__":
    global_agent = A3CAgent(action_size=3)
    global_agent.train()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 20, 16)        4112
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 32)          8224
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               663808
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 676,915
# Trainable params: 676,915
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 20, 16)        4112
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 32)          8224
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               663808
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 676,401
# Trainable params: 676,401
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.
#
# INFO:tensorflow:Summary name Total Reward/Episode is illegal; using Total_Reward/Episode instead.
# INFO:tensorflow:Summary name Average Max Prob/Episode is illegal; using Average_Max_Prob/Episode instead.
# Wait for 8 seconds...
# TensorBoard link:
# https://ca77d0bc.ngrok.io
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorboardcolab/core.py:49: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 16)        4112
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 32)          8224
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               663808
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 676,915
# Trainable params: 676,915
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 16)        4112
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 32)          8224
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               663808
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 676,401
# Trainable params: 676,401
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 20, 20, 16)        4112
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 9, 9, 32)          8224
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               663808
# _________________________________________________________________
# dense_8 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 676,915
# Trainable params: 676,915
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 20, 20, 16)        4112
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 9, 9, 32)          8224
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               663808
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 676,401
# Trainable params: 676,401
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 20, 20, 16)        4112
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 9, 9, 32)          8224
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               663808
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 676,915
# Trainable params: 676,915
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 20, 20, 16)        4112
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 9, 9, 32)          8224
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               663808
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 676,401
# Trainable params: 676,401
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 20, 20, 16)        4112
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 9, 9, 32)          8224
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               663808
# _________________________________________________________________
# dense_14 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 676,915
# Trainable params: 676,915
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 20, 20, 16)        4112
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 9, 9, 32)          8224
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               663808
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 676,401
# Trainable params: 676,401
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 20, 20, 16)        4112
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 9, 9, 32)          8224
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               663808
# _________________________________________________________________
# dense_17 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 676,915
# Trainable params: 676,915
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 20, 20, 16)        4112
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 9, 9, 32)          8224
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               663808
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 676,401
# Trainable params: 676,401
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 20, 20, 16)        4112
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 9, 9, 32)          8224
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 256)               663808
# _________________________________________________________________
# dense_20 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 676,915
# Trainable params: 676,915
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 20, 20, 16)        4112
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 9, 9, 32)          8224
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 256)               663808
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 676,401
# Trainable params: 676,401
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 20, 20, 16)        4112
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 9, 9, 32)          8224
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               663808
# _________________________________________________________________
# dense_23 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 676,915
# Trainable params: 676,915
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 20, 20, 16)        4112
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 9, 9, 32)          8224
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               663808
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 676,401
# Trainable params: 676,401
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 20, 20, 16)        4112
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 9, 9, 32)          8224
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_25 (Dense)             (None, 256)               663808
# _________________________________________________________________
# dense_26 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 676,915
# Trainable params: 676,915
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 20, 20, 16)        4112
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 9, 9, 32)          8224
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_25 (Dense)             (None, 256)               663808
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 676,401
# Trainable params: 676,401
# Non-trainable params: 0
# _________________________________________________________________
# episode: 1   score: 0.0   step: 102
# episode: 2   score: 0.0   step: 99
# episode: 3   score: 2.0   step: 174
# episode: 4   score: 2.0   step: 192
# episode: 5   score: 2.0   step: 196
# episode: 6   score: 1.0   step: 132
# episode: 7   score: 2.0   step: 179
# episode: 8   score: 1.0   step: 121
# episode: 9   score: 0.0   step: 124
# episode: 10   score: 0.0   step: 105
# episode: 11   score: 1.0   step: 126
# episode: 12   score: 0.0   step: 95
# episode: 13   score: 0.0   step: 119
# episode: 14   score: 4.0   step: 268
# episode: 15   score: 6.0   step: 339
# episode: 16   score: 1.0   step: 133
# episode: 17   score: 3.0   step: 258
# episode: 18   score: 1.0   step: 125
# episode: 19   score: 2.0   step: 162
# episode: 20   score: 0.0   step: 94
# episode: 21   score: 1.0   step: 144
# episode: 22   score: 0.0   step: 122
# episode: 23   score: 0.0   step: 105
# episode: 24   score: 4.0   step: 283
# episode: 25   score: 2.0   step: 164
# episode: 26   score: 1.0   step: 122
# episode: 27   score: 1.0   step: 144
# episode: 28   score: 0.0   step: 114
# episode: 29   score: 0.0   step: 109
# episode: 30   score: 2.0   step: 216
# episode: 31   score: 2.0   step: 176
# episode: 32   score: 0.0   step: 96
# episode: 33   score: 1.0   step: 126
# episode: 34   score: 1.0   step: 150
# episode: 35   score: 1.0   step: 161
# episode: 36   score: 2.0   step: 188
# episode: 37   score: 2.0   step: 176
# episode: 38   score: 4.0   step: 247
# episode: 39   score: 0.0   step: 96
# episode: 40   score: 2.0   step: 195
# episode: 41   score: 5.0   step: 292
# episode: 42   score: 0.0   step: 107
# episode: 43   score: 1.0   step: 147
# episode: 44   score: 0.0   step: 108
# episode: 45   score: 3.0   step: 205
# episode: 46   score: 0.0   step: 112
# episode: 47   score: 0.0   step: 94
# episode: 48   score: 3.0   step: 223
# episode: 49   score: 1.0   step: 125
# episode: 50   score: 0.0   step: 117
# episode: 51   score: 0.0   step: 97
# episode: 52   score: 0.0   step: 104
# episode: 53   score: 1.0   step: 143
# episode: 54   score: 1.0   step: 133
# episode: 55   score: 1.0   step: 143
# episode: 56   score: 1.0   step: 122
# episode: 57   score: 2.0   step: 190
# episode: 58   score: 0.0   step: 114
# episode: 59   score: 1.0   step: 123
# episode: 60   score: 5.0   step: 334
# episode: 61   score: 1.0   step: 128
# episode: 62   score: 0.0   step: 99
# episode: 63   score: 1.0   step: 128
# episode: 64   score: 3.0   step: 243
# episode: 65   score: 2.0   step: 151
# episode: 66   score: 1.0   step: 133
# episode: 67   score: 0.0   step: 103
# episode: 68   score: 2.0   step: 166
# episode: 69   score: 0.0   step: 94
# episode: 70   score: 1.0   step: 128
# episode: 71   score: 2.0   step: 176
# episode: 72   score: 1.0   step: 149
# episode: 73   score: 2.0   step: 181
# episode: 74   score: 2.0   step: 177
# episode: 75   score: 2.0   step: 198
# episode: 76   score: 1.0   step: 124
# episode: 77   score: 4.0   step: 249
# episode: 78   score: 1.0   step: 164
# episode: 79   score: 3.0   step: 223
# episode: 80   score: 0.0   step: 98
# episode: 81   score: 2.0   step: 171
# episode: 82   score: 1.0   step: 130
# episode: 83   score: 2.0   step: 194
# episode: 84   score: 2.0   step: 173
# episode: 85   score: 0.0   step: 117
# episode: 86   score: 1.0   step: 160
# episode: 87   score: 1.0   step: 146
# episode: 88   score: 0.0   step: 103
# episode: 89   score: 2.0   step: 159
# episode: 90   score: 5.0   step: 244
# episode: 91   score: 2.0   step: 160
# episode: 92   score: 0.0   step: 110
# episode: 93   score: 2.0   step: 171
# episode: 94   score: 1.0   step: 145
# episode: 95   score: 0.0   step: 108
# episode: 96   score: 2.0   step: 186
# episode: 97   score: 3.0   step: 203
# episode: 98   score: 0.0   step: 95
# episode: 99   score: 1.0   step: 134
# episode: 100   score: 1.0   step: 127
# episode: 101   score: 0.0   step: 95
# episode: 102   score: 1.0   step: 145
# episode: 103   score: 0.0   step: 104
# episode: 104   score: 2.0   step: 182
# episode: 105   score: 1.0   step: 126
# episode: 106   score: 2.0   step: 178
# episode: 107   score: 3.0   step: 221
# episode: 108   score: 2.0   step: 184
# episode: 109   score: 3.0   step: 187
# episode: 110   score: 1.0   step: 134
# episode: 111   score: 1.0   step: 165
# episode: 112   score: 1.0   step: 157
# episode: 113   score: 0.0   step: 98
# episode: 114   score: 1.0   step: 136
# episode: 115   score: 2.0   step: 201
# episode: 116   score: 1.0   step: 149
# episode: 117   score: 1.0   step: 167
# episode: 118   score: 2.0   step: 155
# episode: 119   score: 0.0   step: 119
# episode: 120   score: 0.0   step: 115
# episode: 121   score: 1.0   step: 159
# episode: 122   score: 2.0   step: 184
# episode: 123   score: 1.0   step: 138
# episode: 124   score: 2.0   step: 188
# episode: 125   score: 4.0   step: 310
# episode: 126   score: 2.0   step: 194
# episode: 127   score: 1.0   step: 159
# episode: 128   score: 2.0   step: 181
# episode: 129   score: 1.0   step: 165
# episode: 130   score: 2.0   step: 173
# episode: 131   score: 0.0   step: 114
# episode: 132   score: 3.0   step: 198
# episode: 133   score: 0.0   step: 108
# episode: 134   score: 3.0   step: 237
# episode: 135   score: 1.0   step: 148
# episode: 136   score: 2.0   step: 209
# episode: 137   score: 1.0   step: 149
# episode: 138   score: 0.0   step: 113
# episode: 139   score: 1.0   step: 149
# episode: 140   score: 0.0   step: 108
# episode: 141   score: 1.0   step: 121
# episode: 142   score: 2.0   step: 198
# episode: 143   score: 2.0   step: 216
# episode: 144   score: 1.0   step: 171
# episode: 145   score: 1.0   step: 142
# episode: 146   score: 1.0   step: 144
# episode: 147   score: 0.0   step: 107
# episode: 148   score: 0.0   step: 97
# episode: 149   score: 4.0   step: 253
# episode: 150   score: 3.0   step: 193
# episode: 151   score: 1.0   step: 125
# episode: 152   score: 1.0   step: 149
# episode: 153   score: 2.0   step: 156
# episode: 154   score: 0.0   step: 96
# episode: 155   score: 2.0   step: 174
# episode: 156   score: 1.0   step: 141
# episode: 157   score: 1.0   step: 147
# episode: 158   score: 2.0   step: 177
# episode: 159   score: 1.0   step: 143
# episode: 160   score: 2.0   step: 200
# episode: 161   score: 1.0   step: 124
# episode: 162   score: 0.0   step: 94
# episode: 163   score: 3.0   step: 218
# episode: 164   score: 0.0   step: 100
# episode: 165   score: 2.0   step: 172
# episode: 166   score: 0.0   step: 121
# episode: 167   score: 1.0   step: 148
# episode: 168   score: 3.0   step: 199
# episode: 169   score: 0.0   step: 94
# episode: 170   score: 5.0   step: 295
# episode: 171   score: 3.0   step: 245
# episode: 172   score: 0.0   step: 101
# episode: 173   score: 2.0   step: 211
# episode: 174   score: 3.0   step: 230
# episode: 175   score: 2.0   step: 186
# episode: 176   score: 0.0   step: 95
# episode: 177   score: 2.0   step: 179
# episode: 178   score: 1.0   step: 131
# episode: 179   score: 1.0   step: 124
# episode: 180   score: 3.0   step: 228
# episode: 181   score: 0.0   step: 100
# episode: 182   score: 1.0   step: 160
# episode: 183   score: 1.0   step: 136
# episode: 184   score: 0.0   step: 93
# episode: 185   score: 2.0   step: 195
# episode: 186   score: 2.0   step: 178
# episode: 187   score: 1.0   step: 144
# episode: 188   score: 0.0   step: 104
# episode: 189   score: 1.0   step: 155
# episode: 190   score: 2.0   step: 150
# episode: 191   score: 1.0   step: 145
# episode: 192   score: 2.0   step: 209
# episode: 193   score: 0.0   step: 119
# episode: 194   score: 2.0   step: 180
# episode: 195   score: 0.0   step: 105
# episode: 196   score: 0.0   step: 100
# episode: 197   score: 0.0   step: 120
# episode: 198   score: 1.0   step: 142
# episode: 199   score: 1.0   step: 168
# episode: 200   score: 0.0   step: 107
# episode: 201   score: 0.0   step: 114
# episode: 202   score: 0.0   step: 106
# episode: 203   score: 0.0   step: 123
# episode: 204   score: 0.0   step: 121
# episode: 205   score: 1.0   step: 121
# episode: 206   score: 0.0   step: 94
# episode: 207   score: 1.0   step: 149
# episode: 208   score: 1.0   step: 165
# episode: 209   score: 3.0   step: 205
# episode: 210   score: 1.0   step: 125
# episode: 211   score: 1.0   step: 137
# episode: 212   score: 0.0   step: 106
# episode: 213   score: 1.0   step: 146
# episode: 214   score: 0.0   step: 122
# episode: 215   score: 2.0   step: 189
# episode: 216   score: 0.0   step: 94
# episode: 217   score: 4.0   step: 249
# episode: 218   score: 1.0   step: 135
# episode: 219   score: 1.0   step: 159
# episode: 220   score: 0.0   step: 114
# episode: 221   score: 2.0   step: 154
# episode: 222   score: 1.0   step: 124
# episode: 223   score: 0.0   step: 112
# episode: 224   score: 1.0   step: 122
# episode: 225   score: 1.0   step: 166
# episode: 226   score: 2.0   step: 193
# episode: 227   score: 3.0   step: 183
# episode: 228   score: 0.0   step: 109
# episode: 229   score: 1.0   step: 140
# episode: 230   score: 0.0   step: 105
# episode: 231   score: 1.0   step: 139
# episode: 232   score: 0.0   step: 108
# episode: 233   score: 0.0   step: 99
# episode: 234   score: 1.0   step: 139
# episode: 235   score: 0.0   step: 107
# episode: 236   score: 0.0   step: 101
# episode: 237   score: 0.0   step: 102
# episode: 238   score: 3.0   step: 240
# episode: 239   score: 0.0   step: 92
# episode: 240   score: 0.0   step: 117
# episode: 241   score: 4.0   step: 282
# episode: 242   score: 1.0   step: 166
# episode: 243   score: 2.0   step: 182
# episode: 244   score: 1.0   step: 160
# episode: 245   score: 2.0   step: 185
# episode: 246   score: 0.0   step: 120
# episode: 247   score: 0.0   step: 109
# episode: 248   score: 2.0   step: 167
# episode: 249   score: 0.0   step: 105
# episode: 250   score: 1.0   step: 133
# episode: 251   score: 0.0   step: 112
# episode: 252   score: 1.0   step: 155
# episode: 253   score: 0.0   step: 96
# episode: 254   score: 0.0   step: 105
# episode: 255   score: 0.0   step: 100
# episode: 256   score: 2.0   step: 202
# episode: 257   score: 3.0   step: 190
# episode: 258   score: 1.0   step: 148
# episode: 259   score: 1.0   step: 160
# episode: 260   score: 3.0   step: 227
# episode: 261   score: 3.0   step: 247
# episode: 262   score: 4.0   step: 257
# episode: 263   score: 2.0   step: 190
# episode: 264   score: 0.0   step: 117
# episode: 265   score: 0.0   step: 96
# episode: 266   score: 1.0   step: 165
# episode: 267   score: 1.0   step: 153
# episode: 268   score: 1.0   step: 162
# episode: 269   score: 2.0   step: 175
# episode: 270   score: 0.0   step: 97
# episode: 271   score: 2.0   step: 186
# episode: 272   score: 2.0   step: 183
# episode: 273   score: 3.0   step: 255
# episode: 274   score: 2.0   step: 175
# episode: 275   score: 2.0   step: 193
# episode: 276   score: 2.0   step: 190
# episode: 277   score: 0.0   step: 104
# episode: 278   score: 0.0   step: 97
# episode: 279   score: 2.0   step: 183
# episode: 280   score: 2.0   step: 176
# episode: 281   score: 1.0   step: 158
# episode: 282   score: 4.0   step: 285
# episode: 283   score: 2.0   step: 178
# episode: 284   score: 4.0   step: 294
# episode: 285   score: 3.0   step: 216
# episode: 286   score: 2.0   step: 184
# episode: 287   score: 1.0   step: 169
# episode: 288   score: 4.0   step: 264
# episode: 289   score: 0.0   step: 118
# episode: 290   score: 2.0   step: 187
# episode: 291   score: 3.0   step: 245
# episode: 292   score: 2.0   step: 168
# episode: 293   score: 2.0   step: 177
# episode: 294   score: 2.0   step: 194
# episode: 295   score: 2.0   step: 169
# episode: 296   score: 2.0   step: 181
# episode: 297   score: 0.0   step: 112
# episode: 298   score: 5.0   step: 305
# episode: 299   score: 2.0   step: 178
# episode: 300   score: 2.0   step: 197
# episode: 301   score: 3.0   step: 238
# episode: 302   score: 2.0   step: 185
# episode: 303   score: 0.0   step: 119
# episode: 304   score: 0.0   step: 106
# episode: 305   score: 3.0   step: 225
# episode: 306   score: 2.0   step: 215
# episode: 307   score: 2.0   step: 187
# episode: 308   score: 0.0   step: 104
# episode: 309   score: 1.0   step: 162
# episode: 310   score: 1.0   step: 137
# episode: 311   score: 2.0   step: 212
# episode: 312   score: 0.0   step: 122
# episode: 313   score: 2.0   step: 175
# episode: 314   score: 0.0   step: 114
# episode: 315   score: 2.0   step: 182
# episode: 316   score: 2.0   step: 193
# episode: 317   score: 2.0   step: 195
# episode: 318   score: 2.0   step: 186
# episode: 319   score: 2.0   step: 208
# episode: 320   score: 2.0   step: 181
# episode: 321   score: 2.0   step: 189
# episode: 322   score: 0.0   step: 103
# episode: 323   score: 0.0   step: 108
# episode: 324   score: 0.0   step: 113
# episode: 325   score: 0.0   step: 112
# episode: 326   score: 2.0   step: 168
# episode: 327   score: 0.0   step: 124
# episode: 328   score: 0.0   step: 108
# episode: 329   score: 0.0   step: 112
# episode: 330   score: 3.0   step: 246
# episode: 331   score: 4.0   step: 281
# episode: 332   score: 1.0   step: 133
# episode: 333   score: 2.0   step: 183
# episode: 334   score: 1.0   step: 143
# episode: 335   score: 2.0   step: 191
# episode: 336   score: 0.0   step: 121
# episode: 337   score: 1.0   step: 167
# episode: 338   score: 0.0   step: 94
# episode: 339   score: 0.0   step: 109
# episode: 340   score: 2.0   step: 185
# episode: 341   score: 2.0   step: 157
# episode: 342   score: 0.0   step: 102
# episode: 343   score: 2.0   step: 181
# episode: 344   score: 0.0   step: 103
# episode: 345   score: 1.0   step: 166
# episode: 346   score: 4.0   step: 286
# episode: 347   score: 4.0   step: 272
# episode: 348   score: 1.0   step: 138
# episode: 349   score: 3.0   step: 204
# episode: 350   score: 0.0   step: 105
# episode: 351   score: 3.0   step: 266
# episode: 352   score: 4.0   step: 288
# episode: 353   score: 0.0   step: 115
# episode: 354   score: 0.0   step: 110
# episode: 355   score: 0.0   step: 121
# episode: 356   score: 2.0   step: 204
# episode: 357   score: 0.0   step: 106
# episode: 358   score: 0.0   step: 116
# episode: 359   score: 0.0   step: 104
# episode: 360   score: 0.0   step: 102
# episode: 361   score: 0.0   step: 105
# episode: 362   score: 0.0   step: 111
# episode: 363   score: 2.0   step: 189
# episode: 364   score: 2.0   step: 192
# episode: 365   score: 3.0   step: 210
# episode: 366   score: 1.0   step: 134
# episode: 367   score: 2.0   step: 181
# episode: 368   score: 1.0   step: 121
# episode: 369   score: 0.0   step: 121
# episode: 370   score: 0.0   step: 110
# episode: 371   score: 0.0   step: 99
# episode: 372   score: 1.0   step: 129
# episode: 373   score: 2.0   step: 206
# episode: 374   score: 2.0   step: 196
# episode: 375   score: 1.0   step: 135
# episode: 376   score: 1.0   step: 154
# episode: 377   score: 0.0   step: 101
# episode: 378   score: 1.0   step: 149
# episode: 379   score: 0.0   step: 103
# episode: 380   score: 0.0   step: 97
# episode: 381   score: 2.0   step: 176
# episode: 382   score: 0.0   step: 122
# episode: 383   score: 2.0   step: 179
# episode: 384   score: 1.0   step: 141
# episode: 385   score: 2.0   step: 198
# episode: 386   score: 2.0   step: 183
# episode: 387   score: 3.0   step: 238
# episode: 388   score: 0.0   step: 101
# episode: 389   score: 3.0   step: 244
# episode: 390   score: 1.0   step: 141
# episode: 391   score: 1.0   step: 145
# episode: 392   score: 3.0   step: 218
# episode: 393   score: 2.0   step: 181
# episode: 394   score: 1.0   step: 139
# episode: 395   score: 1.0   step: 133
# episode: 396   score: 1.0   step: 140
# episode: 397   score: 1.0   step: 122
# episode: 398   score: 2.0   step: 192
# episode: 399   score: 1.0   step: 128
# episode: 400   score: 1.0   step: 135
# episode: 401   score: 2.0   step: 186
# episode: 402   score: 4.0   step: 285
# episode: 403   score: 1.0   step: 168
# episode: 404   score: 0.0   step: 112
# episode: 405   score: 1.0   step: 136
# episode: 406   score: 0.0   step: 104
# episode: 407   score: 3.0   step: 245
# episode: 408   score: 1.0   step: 137
# episode: 409   score: 0.0   step: 111
# episode: 410   score: 3.0   step: 225
# episode: 411   score: 0.0   step: 121
# episode: 412   score: 1.0   step: 145
# episode: 413   score: 1.0   step: 148
# episode: 414   score: 2.0   step: 167
# episode: 415   score: 2.0   step: 161
# episode: 416   score: 1.0   step: 143
# episode: 417   score: 1.0   step: 122
# episode: 418   score: 4.0   step: 286
# episode: 419   score: 0.0   step: 118
# episode: 420   score: 2.0   step: 195
# episode: 421   score: 3.0   step: 243
# episode: 422   score: 1.0   step: 136
# episode: 423   score: 4.0   step: 263
# episode: 424   score: 4.0   step: 271
# episode: 425   score: 1.0   step: 166
# episode: 426   score: 0.0   step: 120
# episode: 427   score: 2.0   step: 191
# episode: 428   score: 3.0   step: 237
# episode: 429   score: 1.0   step: 133
# episode: 430   score: 1.0   step: 165
# episode: 431   score: 0.0   step: 107
# episode: 432   score: 0.0   step: 95
# episode: 433   score: 1.0   step: 150
# episode: 434   score: 2.0   step: 170
# episode: 435   score: 0.0   step: 94
# episode: 436   score: 0.0   step: 98
# episode: 437   score: 3.0   step: 200
# episode: 438   score: 2.0   step: 172
# episode: 439   score: 3.0   step: 219
# episode: 440   score: 3.0   step: 238
# episode: 441   score: 0.0   step: 123
# episode: 442   score: 4.0   step: 269
# episode: 443   score: 2.0   step: 170
# episode: 444   score: 1.0   step: 130
# episode: 445   score: 0.0   step: 105
# episode: 446   score: 5.0   step: 317
# episode: 447   score: 1.0   step: 127
# episode: 448   score: 0.0   step: 109
# episode: 449   score: 0.0   step: 104
# episode: 450   score: 2.0   step: 206
# episode: 451   score: 1.0   step: 125
# episode: 452   score: 3.0   step: 249
# episode: 453   score: 0.0   step: 93
# episode: 454   score: 0.0   step: 119
# episode: 455   score: 0.0   step: 108
# episode: 456   score: 0.0   step: 102
# episode: 457   score: 0.0   step: 107
# episode: 458   score: 2.0   step: 190
# episode: 459   score: 3.0   step: 233
# episode: 460   score: 2.0   step: 205
# episode: 461   score: 0.0   step: 123
# episode: 462   score: 1.0   step: 152
# episode: 463   score: 0.0   step: 97
# episode: 464   score: 0.0   step: 99
# episode: 465   score: 0.0   step: 100
# episode: 466   score: 1.0   step: 162
# episode: 467   score: 1.0   step: 165
# episode: 468   score: 2.0   step: 198
# episode: 469   score: 0.0   step: 101
# episode: 470   score: 2.0   step: 187
# episode: 471   score: 0.0   step: 99
# episode: 472   score: 2.0   step: 175
# episode: 473   score: 2.0   step: 170
# episode: 474   score: 2.0   step: 183
# episode: 475   score: 2.0   step: 189
# episode: 476   score: 0.0   step: 110
# episode: 477   score: 1.0   step: 143
# episode: 478   score: 9.0   step: 369
# episode: 479   score: 0.0   step: 104
# episode: 480   score: 1.0   step: 149
# episode: 481   score: 1.0   step: 139
# episode: 482   score: 3.0   step: 263
# episode: 483   score: 4.0   step: 272
# episode: 484   score: 0.0   step: 119
# episode: 485   score: 0.0   step: 99
# episode: 486   score: 1.0   step: 148
# episode: 487   score: 2.0   step: 187
# episode: 488   score: 1.0   step: 146
# episode: 489   score: 0.0   step: 97
# episode: 490   score: 2.0   step: 187
# episode: 491   score: 1.0   step: 142
# episode: 492   score: 0.0   step: 121
# episode: 493   score: 3.0   step: 241
# episode: 494   score: 2.0   step: 188
# episode: 495   score: 3.0   step: 217
# episode: 496   score: 0.0   step: 120
# episode: 497   score: 1.0   step: 144
# episode: 498   score: 3.0   step: 208
# episode: 499   score: 2.0   step: 192
# episode: 500   score: 0.0   step: 107
# episode: 501   score: 0.0   step: 120
# episode: 502   score: 1.0   step: 139
# episode: 503   score: 1.0   step: 139
# episode: 504   score: 1.0   step: 160
# episode: 505   score: 2.0   step: 189
# episode: 506   score: 2.0   step: 191
# episode: 507   score: 1.0   step: 161
# episode: 508   score: 3.0   step: 241
# episode: 509   score: 2.0   step: 170
# episode: 510   score: 0.0   step: 121
# episode: 511   score: 1.0   step: 149
# episode: 512   score: 4.0   step: 268
# episode: 513   score: 0.0   step: 114
# episode: 514   score: 1.0   step: 133
# episode: 515   score: 0.0   step: 114
# episode: 516   score: 0.0   step: 112
# episode: 517   score: 1.0   step: 147
# episode: 518   score: 2.0   step: 201
# episode: 519   score: 1.0   step: 140
# episode: 520   score: 0.0   step: 105
# episode: 521   score: 1.0   step: 121
# episode: 522   score: 0.0   step: 98
# episode: 523   score: 0.0   step: 109
# episode: 524   score: 1.0   step: 156
# episode: 525   score: 0.0   step: 107
# episode: 526   score: 0.0   step: 97
# episode: 527   score: 0.0   step: 93
# episode: 528   score: 1.0   step: 150
# episode: 529   score: 3.0   step: 232
# episode: 530   score: 2.0   step: 208
# episode: 531   score: 2.0   step: episode:157
# 532   score: 2.0   step: 197
# episode: 533   score: 0.0   step: 104
# episode: 534   score: 1.0   step: 138
# episode: 535   score: 1.0   step: 169
# episode: 536   score: 1.0   step: 149
# episode: 537   score: 0.0   step: 95
# episode: 538   score: 0.0   step: 98
# episode: 539   score: 0.0   step: 94
# episode: 540   score: 2.0   step: 192
# episode: 541   score: 0.0   step: 118
# episode: 542   score: 0.0   step: 107
# episode: 543   score: 3.0   step: 199
# episode: 544   score: 3.0   step: 222
# episode: 545   score: 2.0   step: 182
# episode: 546   score: 1.0   step: 123
# episode: 547   score: 1.0   step: 164
# episode: 548   score: 2.0   step: 193
# episode: 549   score: 2.0   step: 189
# episode: 550   score: 1.0   step: 136
# episode: 551   score: 2.0   step: 174
# episode: 552   score: 0.0   step: 103
# episode: 553   score: 5.0   step: 296
# episode: 554   score: 2.0   step: 186
# episode: 555   score: 1.0   step: 128
# episode: 556   score: 0.0   step: 98
# episode: 557   score: 1.0   step: 136
# episode: 558   score: 2.0   step: 196
# episode: 559   score: 3.0   step: 239
# episode: 560   score: 1.0   step: 146
# episode: 561   score: 1.0   step: 129
# episode: 562   score: 3.0   step: 213
# episode: 563   score: 2.0   step: 194
# episode: 564   score: 3.0   step: 201
# episode: 565   score: 1.0   step: 155
# episode: 566   score: 0.0   step: 120
# episode: 567   score: 2.0   step: 169
# episode: 568   score: 2.0   step: 193
# episode: 569   score: 2.0   step: 183
# episode: 570   score: 1.0   step: 146
# episode: 571   score: 0.0   step: 122
# episode: 572   score: 2.0   step: 189
# episode: 573   score: 0.0   step: 98
# episode: 574   score: 0.0   step: 103
# episode: 575   score: 3.0   step: 247
# episode: 576   score: 3.0   step: 240
# episode: 577   score: 3.0   step: 225
# episode: 578   score: 0.0   step: 105
# episode: 579   score: 3.0   step: 211
# episode: 580   score: 1.0   step: 166
# episode: 581   score: 0.0   step: 120
# episode: 582   score: 1.0   step: 162
# episode: 583   score: 3.0   step: 232
# episode: 584   score: 0.0   step: 122
# episode: 585   score: 2.0   step: 194
# episode: 586   score: 0.0   step: 102
# episode: 587   score: 3.0   step: 212
# episode: 588   score: 2.0   step: 181
# episode: 589   score: 0.0   step: 108
# episode: 590   score: 0.0   step: 113
# episode: 591   score: 2.0   step: 215
# episode: 592   score: 3.0   step: 226
# episode: 593   score: 2.0   step: 154
# episode: 594   score: 1.0   step: 143
# episode: 595   score: 1.0   step: 147
# episode: 596   score: 2.0   step: 206
# episode: 597   score: 1.0   step: 150
# episode: 598   score: 5.0   step: 323
# episode: 599   score: 1.0   step: 150
# episode: 600   score: 1.0   step: 155
# episode: 601   score: 1.0   step: 138
# episode: 602   score: 3.0   step: 218
# episode: 603   score: 2.0   step: 185
# episode: 604   score: 2.0   step: 190
# episode: 605   score: 1.0   step: 149
# episode: 606   score: 3.0   step: 205
# episode: 607   score: 0.0   step: 113
# episode: 608   score: 4.0   step: 263
# episode: 609   score: 2.0   step: 182
# episode: 610   score: 2.0   step: 191
# episode: 611   score: 3.0   step: 197
# episode: 612   score: 0.0   step: 108
# episode: 613   score: 4.0   step: 308
# episode: 614   score: 0.0   step: 110
# episode: 615   score: 1.0   step: 126
# episode: 616   score: 2.0   step: 192
# episode: 617   score: 2.0   step: 205
# episode: 618   score: 1.0   step: 149
# episode: 619   score: 1.0   step: 155
# episode: 620   score: 1.0   step: 162
# episode: 621   score: 2.0   step: 169
# episode: 622   score: 0.0   step: 121
# episode: 623   score: 0.0   step: 116
# episode: 624   score: 0.0   step: 109
# episode: 625   score: 0.0   step: 122
# episode: 626   score: 0.0   step: 106
# episode: 627   score: 1.0   step: 140
# episode: 628   score: 2.0   step: 189
# episode: 629   score: 2.0   step: 182
# episode: 630   score: 1.0   step: 164
# episode: 631   score: 0.0   step: 121
# episode: 632   score: 0.0   step: 105
# episode: 633   score: 2.0   step: 216
# episode: 634   score: 1.0   step: 142
# episode: 635   score: 1.0   step: 164
# episode: 636   score: 1.0   step: 148
# episode: 637   score: 1.0   step: 167
# episode: 638   score: 0.0   step: 122
# episode: 639   score: 0.0   step: 121
# episode: 640   score: 0.0   step: 118
# episode: 641   score: 0.0   step: 111
# episode: 642   score: 0.0   step: 105
# episode: 643   score: 0.0   step: 101
# episode: 644   score: 0.0   step: 117
# episode: 645   score: 0.0   step: 104
# episode: 646   score: 2.0   step: 200
# episode: 647   score: 4.0   step: 289
# episode: 648   score: 1.0   step: 131
# episode: 649   score: 4.0   step: 265
# episode: 650   score: 2.0   step: 195
# episode: 651   score: 0.0   step: 95
# episode: 652   score: 0.0   step: 119
# episode: 653   score: 0.0   step: 122
# episode: 654   score: 0.0   step: 117
# episode: 655   score: 0.0   step: 98
# episode: 656   score: 1.0   step: 142
# episode: 657   score: 1.0   step: 156
# episode: 658   score: 2.0   step: 171
# episode: 659   score: 3.0   step: 225
# episode: 660   score: 2.0   step: 173
# episode: 661   score: 3.0   step: 241
# episode: 662   score: 0.0   step: 101
# episode: 663   score: 1.0   step: 160
# episode: 664   score: 4.0   step: 268
# episode: 665   score: 0.0   step: 109
# episode: 666   score: 2.0   step: 217
# episode: 667   score: 1.0   step: 162
# episode: 668   score: 0.0   step: 120
# episode: 669   score: 1.0   step: 158
# episode: 670   score: 0.0   step: 95
# episode: 671   score: 1.0   step: 142
# episode: 672   score: 0.0   step: 115
# episode: 673   score: 1.0   step: 147
# episode: 674   score: 0.0   step: 105
# episode: 675   score: 3.0   step: 229
# episode: 676   score: 0.0   step: 114
# episode: 677   score: 0.0   step: 93
# episode: 678   score: 0.0   step: 105
# episode: 679   score: 0.0   step: 114
# episode: 680   score: 3.0   step: 202
# episode: 681   score: 0.0   step: 119
# episode: 682   score: 0.0   step: 107
# episode: 683   score: 0.0   step: 122
# episode: 684   score: 2.0   step: 169
# episode: 685   score: 0.0   step: 112
# episode: 686   score: 0.0   step: 114
# episode: 687   score: 1.0   step: 139
# episode: 688   score: 0.0   step: 112
# ...
# episode: 10438   score: 13.0   step: 458
# episode: 10439   score: 8.0   step: 374
# episode: 10440   score: 7.0   step: 400
# episode: 10441   score: 19.0   step: 415
# episode: 10442   score: 11.0   step: 512
# episode: 10443   score: 6.0   step: 312
# episode: 10444   score: 11.0   step: 372
# episode: 10445   score: 17.0   step: 433
# episode: 10446   score: 9.0   step: 331
# episode: 10447   score: 19.0   step: 425
# episode: 10448   score: 34.0   step: 697
# episode: 10449   score: 8.0   step: 392
# episode: 10450   score: 16.0   step: 414
# episode: 10451   score: 19.0   step: 616
# episode: 10452   score: 18.0   step: 496
# episode: 10453   score: 14.0   step: 395
# episode: 10454   score: 16.0   step: 451
# episode: 10455   score: 8.0   step: 381
# episode: 10456   score: 12.0   step: 402
# episode: 10457   score: 4.0   step: 248
# episode: 10458   score: 17.0   step: 445
# episode: 10459   score: 10.0   step: 344
# episode: 10460   score: 17.0   step: 508
# episode: 10461   score: 8.0   step: 393
# episode: 10462   score: 11.0   step: 479
# episode: 10463   score: 15.0   step: 408
# episode: 10464   score: 12.0   step: 416
# episode: 10465   score: 14.0   step: 550
# episode: 10466   score: 10.0   step: 318
# episode: 10467   score: 18.0   step: 539
# episode: 10468   score: 14.0   step: 512
# episode: 10469   score: 4.0   step: 249
# episode: 10470   score: 15.0   step: 382
# episode: 10471   score: 11.0   step: 400
# episode: 10472   score: 14.0   step: 509
# episode: 10473   score: 6.0   step: 334
# episode: 10474   score: 13.0   step: 437
# episode: 10475   score: 12.0   step: 469
# episode: 10476   score: 20.0   step: 433
# episode: 10477   score: 7.0   step: 346
# episode: 10478   score: 13.0   step: 364
# episode: 10479   score: 26.0   step: 635
# episode: 10480   score: 23.0   step: 613
# episode: 10481   score: 28.0   step: 623
# episode: 10482   score: 20.0   step: 461
# episode: 10483   score: 8.0   step: 386
# episode: 10484   score: 25.0   step: 729
# episode: 10485   score: 12.0   step: 460
# episode: 10486   score: 11.0   step: 415
# episode: 10487   score: 14.0   step: 628
# episode: 10488   score: 7.0   step: 368
# episode: 10489   score: 11.0   step: 415
# episode: 10490   score: 3.0   step: 195
# episode: 10491   score: 4.0   step: 242
# episode: 10492   score: 20.0   step: 499
# episode: 10493   score: 5.0   step: 281
# episode: 10494   score: 26.0   step: 617
# episode: 10495   score: 11.0   step: 421
# episode: 10496   score: 8.0   step: 448
# episode: 10497   score: 10.0   step: 486
# episode: 10498   score: 19.0   step: 544
# episode: 10499   score: 7.0   step: 359
# episode: 10500   score: 8.0   step: 395
# episode: 10501   score: 7.0   step: 374
# episode: 10502   score: 7.0   step: 341
# episode: 10503   score: 13.0   step: 312
# episode: 10504   score: 17.0   step: 479
# episode: 10505   score: 25.0   step: 485
# episode: 10506   score: 28.0   step: 666
# episode: 10507   score: 9.0   step: 458
# episode: 10508   score: 6.0   step: 324
# episode: 10509   score: 8.0   step: 404
# episode: 10510   score: 9.0   step: 303
# episode: 10511   score: 16.0   step: 464
# episode: 10512   score: 23.0   step: 562
# episode: 10513   score: 20.0   step: 668
# episode: 10514   score: 17.0   step: 605
# episode: 10515   score: 17.0   step: 594
# episode: 10516   score: 11.0   step: 332
# episode: 10517   score: 11.0   step: 381
# episode: 10518   score: 6.0   step: 311
# episode: 10519   score: 10.0   step: 427
# episode: 10520   score: 9.0   step: 323
# episode: 10521   score: 3.0   step: 216
# episode: 10522   score: 16.0   step: 318
# episode: 10523   score: 12.0   step: 279
# episode: 10524   score: 10.0   step: 344
# episode: 10525   score: 3.0   step: 194
# episode: 10526   score: 8.0   step: 283
# episode: 10527   score: 11.0   step: 258
# episode: 10528   score: 3.0   step: 185
# episode: 10529   score: 7.0   step: 229
# episode: 10530   score: 3.0   step: 184
# episode: 10531   score: 7.0   step: 229
# episode: 10532   score: 11.0   step: 264
# episode: 10533   score: 7.0   step: 222
# episode: 10534   score: 11.0   step: 266
# episode: 10535   score: 7.0   step: 227
# episode: 10536   score: 7.0   step: 226
# episode: 10537   score: 7.0   step: 224
# episode: 10538   score: 11.0   step: 256
# episode: 10539   score: 3.0   step: 185
# episode: 10540   score: 3.0   step: 186
# episode: 10541   score: 7.0   step: 230
# episode: 10542   score: 11.0   step: 394
# episode: 10543   score: 7.0   step: 231
# episode: 10544   score: 7.0   step: 222
# episode: 10545   score: 3.0   step: 194
# episode: 10546   score: 3.0   step: 183
# episode: 10547   score: 7.0   step: 227
# episode: 10548   score: 11.0   step: 256
# episode: 10549   score: 7.0   step: 222
# episode: 10550   score: 7.0   step: 228
# episode: 10551   score: 11.0   step: 260
# episode: 10552   score: 11.0   step: 257
# episode: 10553   score: 11.0   step: 266
# episode: 10554   score: 11.0   step: 265
# episode: 10555   score: 3.0   step: 185
# episode: 10556   score: 11.0   step: 261
# episode: 10557   score: 7.0   step: 231
# episode: 10558   score: 3.0   step: 187
# episode: 10559   score: 7.0   step: 223
# episode: 10560   score: 3.0   step: 188
# episode: 10561   score: 11.0   step: 265
# episode: 10562   score: 7.0   step: 222
# episode: 10563   score: 11.0   step: 260
# episode: 10564   score: 7.0   step: 227
# episode: 10565   score: 7.0   step: 235
# episode: 10566   score: 3.0   step: 193
# episode: 10567   score: 11.0   step: 264
# episode: 10568   score: 11.0   step: 257
# episode: 10569   score: 7.0   step: 231
# episode: 10570   score: 11.0   step: 259
# episode: 10571   score: 7.0   step: 227
# episode: 10572   score: 11.0   step: 263
# episode: 10573   score: 4.0   step: 234
# episode: 10574   score: 15.0   step: 376
# episode: 10575   score: 9.0   step: 410
# episode: 10576   score: 7.0   step: 343
# episode: 10577   score: 13.0   step: 461
# episode: 10578   score: 7.0   step: 329
# episode: 10579   score: 17.0   step: 458
# episode: 10580   score: 15.0   step: 529
# episode: 10581   score: 12.0   step: 404
# episode: 10582   score: 7.0   step: 234
# episode: 10583   score: 15.0   step: 544
# episode: 10584   score: 17.0   step: 586
# episode: 10585   score: 15.0   step: 534
# episode: 10586   score: 9.0   step: 446
# episode: 10587   score: 20.0   step: 600
# episode: 10588   score: 22.0   step: 499
# episode: 10589   score: 6.0   step: 351
# episode: 10590   score: 7.0   step: 350
# episode: 10591   score: 14.0   step: 493
# episode: 10592   score: 15.0   step: 508
# episode: 10593   score: 11.0   step: 550
# episode: 10594   score: 21.0   step: 473
# episode: 10595   score: 17.0   step: 523
# episode: 10596   score: 19.0   step: 568
# episode: 10597   score: 20.0   step: 413
# episode: 10598   score: 7.0   step: 368
# episode: 10599   score: 21.0   step: 449
# episode: 10600   score: 9.0   step: 422
# episode: 10601   score: 16.0   step: 603
# episode: 10602   score: 19.0   step: 603
# episode: 10603   score: 11.0   step: 481
# episode: 10604   score: 14.0   step: 445
# episode: 10605   score: 5.0   step: 294
# episode: 10606   score: 16.0   step: 523
# episode: 10607   score: 19.0   step: 574
# episode: 10608   score: 22.0   step: 658
# episode: 10609   score: 22.0   step: 472
# episode: 10610   score: 23.0   step: 568
# episode: 10611   score: 7.0   step: 246
# episode: 10612   score: 12.0   step: 536
# episode: 10613   score: 20.0   step: 565
# episode: 10614   score: 22.0   step: 510
# episode: 10615   score: 8.0   step: 382
# episode: 10616   score: 17.0   step: 511
# episode: 10617   score: 13.0   step: 506
# episode: 10618   score: 23.0   step: 599
# episode: 10619   score: 9.0   step: 411
# episode: 10620   score: 17.0   step: episode:548
# 10621   score: 28.0   step: 633
# episode: 10622   score: 24.0   step: 510
# episode: 10623   score: 20.0   step: 436
# episode: 10624   score: 22.0   step: 519
# episode: 10625   score: 16.0   step: 441
# episode: 10626   score: 9.0   step: 435
# episode: 10627   score: 4.0   step: 249
# episode: 10628   score: 6.0   step: 327
# episode: 10629   score: 13.0   step: 318
# episode: 10630   score: 7.0   step: 339
# episode: 10631   score: 20.0   step: 472
# episode: 10632   score: 16.0   step: 323
# episode: 10633   score: 16.0   step: 429
# episode: 10634   score: 19.0   step: 512
# episode: 10635   score: 9.0   step: 427
# episode: 10636   score: 17.0   step: 323
# episode: 10637   score: 21.0   step: 610
# episode: 10638   score: 27.0   step: 474
# episode: 10639   score: 24.0   step: 643
# episode: 10640   score: 16.0   step: 567
# episode: 10641   score: 13.0   step: 455
# episode: 10642   score: 18.0   step: 599
# episode: 10643   score: 12.0   step: 511
# episode: 10644   score: 17.0   step: 620
# episode: 10645   score: 19.0   step: 357
# episode: 10646   score: 20.0   step: 408
# episode: 10647   score: 22.0   step: 522
# episode: 10648   score: 13.0   step: 452
# episode: 10649   score: 4.0   step: 228
# episode: 10650   score: 15.0   step: 503
# episode: 10651   score: 26.0   step: 717
# episode: 10652   score: 8.0   step: 371
# episode: 10653   score: 13.0   step: 471
# episode: 10654   score: 11.0   step: 389
# episode: 10655   score: 12.0   step: 454
# episode: 10656   score: 14.0   step: 495
# episode: 10657   score: 13.0   step: 366
# episode: 10658   score: 8.0   step: 377
# episode: 10659   score: 13.0   step: 446
# episode: 10660   score: 12.0   step: 445
# episode: 10661   score: 21.0   step: 699
# episode: 10662   score: 18.0   step: 480
# episode: 10663   score: 21.0   step: 447
# episode: 10664   score: 9.0   step: 400
# episode: 10665   score: 18.0   step: 530
# episode: 10666   score: 23.0   step: 535
# episode: 10667   score: 18.0   step: 698
# episode: 10668   score: 23.0   step: 679
# episode: 10669   score: 12.0   step: 387
# episode: 10670   score: 13.0   step: 537
# episode: 10671   score: 8.0   step: 286
# episode: 10672   score: 5.0   step: 294
# episode: 10673   score: 13.0   step: 469
# episode: 10674   score: 5.0   step: 296
# episode: 10675   score: 19.0   step: 428
# episode: 10676   score: 11.0   step: 431
# episode: 10677   score: 11.0   step: 410
# episode: 10678   score: 17.0   step: 498
# episode: 10679   score: 8.0   step: 293
# episode: 10680   score: 12.0   step: 414
# episode: 10681   score: 17.0   step: 448
# episode: 10682   score: 6.0   step: 324
# episode: 10683   score: 5.0   step: 296
# episode: 10684   score: 2.0   step: 180
# episode: 10685   score: 10.0   step: 495
# episode: 10686   score: 10.0   step: 382
# episode: 10687   score: 12.0   step: 583
# episode: 10688   score: 32.0   step: 580
# episode: 10689   score: 18.0   step: 662
# episode: 10690   score: 10.0   step: 442
# episode: 10691   score: 22.0   step: 584
# episode: 10692   score: 9.0   step: 381
# episode: 10693   score: 12.0   step: 447
# episode: 10694   score: 9.0   step: 411
# episode: 10695   score: 12.0   step: 391
# episode: 10696   score: 20.0   step: 586
# episode: 10697   score: 11.0   step: 461
# episode: 10698   score: 21.0   step: 684
# episode: 10699   score: 21.0   step: 498
# episode: 10700   score: 7.0   step: 388
# episode: 10701   score: 30.0   step: 638
# episode: 10702   score: 10.0   step: 461
# episode: 10703   score: 12.0   step: 514
# episode: 10704   score: 10.0   step: 472
# episode: 10705   score: 10.0   step: 459
# episode: 10706   score: 31.0   step: 803
# episode: 10707   score: 6.0   step: 299
# episode: 10708   score: 8.0   step: 377
# episode: 10709   score: 15.0   step: 420
# episode: 10710   score: 9.0   step: 411
# episode: 10711   score: 12.0   step: 424
# episode: 10712   score: 9.0   step: 426
# episode: 10713   score: 16.0   step: 546
# episode: 10714   score: 6.0   step: 326
# episode: 10715   score: 26.0   step: 621
# episode: 10716   score: 15.0   step: 533
# episode: 10717   score: 19.0   step: 536
# episode: 10718   score: 10.0   step: 314
# episode: 10719   score: 15.0   step: 534
# episode: 10720   score: 14.0   step: 480
# episode: 10721   score: 29.0   step: 611
# episode: 10722   score: 10.0   step: 420
# episode: 10723   score: 24.0   step: 621
# episode: 10724   score: 11.0   step: 464
# episode: 10725   score: 12.0   step: 524
# episode: 10726   score: 4.0   step: 254
# episode: 10727   score: 18.0   step: 574
# episode: 10728   score: 13.0   step: 461
# episode: 10729   score: 5.0   step: 309
# episode: 10730   score: 21.0   step: 622
# episode: 10731   score: 18.0   step: 621
# episode: 10732   score: 18.0   step: 703
# episode: 10733   score: 16.0   step: 466
# episode: 10734   score: 10.0   step: 464
# episode: 10735   score: 24.0   step: 676
# episode: 10736   score: 6.0   step: 342
# episode: 10737   score: 23.0   step: 523
# episode: 10738   score: 16.0   step: 555
# episode: 10739   score: 18.0   step: 527
# episode: 10740   score: 20.0   step: 657
# episode: 10741   score: 20.0   step: 633
# episode: 10742   score: 13.0   step: 543
# episode: 10743   score: 18.0   step: 478
# episode: 10744   score: 29.0   step: 674
# episode: 10745   score: 8.0   step: 362
# episode: 10746   score: 17.0   step: 587
# episode: 10747   score: 16.0   step: 549
# episode: 10748   score: 8.0   step: 377
# episode: 10749   score: 12.0   step: 502
# episode: 10750   score: 21.0   step: 643
# episode: 10751   score: 12.0   step: 418
# episode: 10752   score: 16.0   step: 410
# episode: 10753   score: 12.0   step: 539
# episode: 10754   score: 17.0   step: 520
# episode: 10755   score: 8.0   step: 389
# episode: 10756   score: 16.0   step: 569
# episode: 10757   score: 7.0   step: 344
# episode: 10758   score: 15.0   step: 553
# episode: 10759   score: 17.0   step: 616
# episode: 10760   score: 24.0   step: 506
# episode: 10761   score: 14.0   step: 534
# episode: 10762   score: 17.0   step: 572
# episode: 10763   score: 14.0   step: 528
# episode: 10764   score: 21.0   step: 446
# episode: 10765   score: 18.0   step: 465
# episode: 10766   score: 30.0   step: 642
# episode: 10767   score: 6.0   step: 338
# episode: 10768   score: 15.0   step: 404
# episode: 10769   score: 20.0   step: 436
# episode: 10770   score: 24.0   step: 661
# episode: 10771   score: 7.0   step: 337
# episode: 10772   score: 20.0   step: 568
# episode: 10773   score: 21.0   step: 628
# episode: 10774   score: 20.0   step: 689
# episode: 10775   score: 13.0   step: 526
# episode: 10776   score: 9.0   step: 468
# episode: 10777   score: 15.0   step: 483
# episode: 10778   score: 25.0   step: 463
# episode: 10779   score: 13.0   step: 515
# episode: 10780   score: 13.0   step: 431
# episode: 10781   score: 13.0   step: 466
# episode: 10782   score: 18.0   step: 528
# episode: 10783   score: 19.0   step: 511
# episode: 10784   score: 27.0   step: 604
# episode: 10785   score: 20.0   step: 536
# episode: 10786   score: 10.0   step: 312
# episode: 10787   score: 12.0   step: 423
# episode: 10788   score: 20.0   step: 498
# episode: 10789   score: 20.0   step: 589
# episode: 10790   score: 19.0   step: 415
# episode: 10791   score: 4.0   step: 258
# episode: 10792   score: 10.0   step: 361
# episode: 10793   score: 9.0   step: 303
# episode: 10794   score: 6.0   step: 296
# episode: 10795   score: 7.0   step: 230
# episode: 10796   score: 7.0   step: 226
# episode: 10797   score: 11.0   step: 256
# episode: 10798   score: 7.0   step: 231
# episode: 10799   score: 7.0   step: 231
# episode: 10800   score: 7.0   step: 227
# episode: 10801   score: 11.0   step: 266
# episode: 10802   score: 3.0   step: 183
# episode: 10803   score: 11.0   step: 261
# episode: 10804   score: 7.0   step: 232
# episode: 10805   score: 11.0   step: 265
# episode: 10806   score: 3.0   step: 184
# episode: 10807   score: 7.0   step: 223
# episode: 10808   score: 3.0   step: 188
# episode: 10809   score: 7.0   step: 222
# episode: 10810   score: 11.0   step: 259
# episode: 10811   score: 7.0   step: 232
# episode: 10812   score: 14.0   step: 349
# episode: 10813   score: 7.0   step: 382
# episode: 10814   score: 13.0   step: 462
# episode: 10815   score: 24.0   step: 466
# episode: 10816   score: 14.0   step: 500
# episode: 10817   score: 23.0   step: 533
# episode: 10818   score: 6.0   step: 349
# episode: 10819   score: 29.0   step: 645
# episode: 10820   score: 25.0   step: 640
# episode: 10821   score: 14.0   step: 388
# episode: 10822   score: 12.0   step: 409
# episode: 10823   score: 22.0   step: 513
# episode: 10824   score: 13.0   step: 335
# episode: 10825   score: 22.0   step: 530
# episode: 10826   score: 13.0   step: 342
# episode: 10827   score: 15.0   step: 507
# episode: 10828   score: 29.0   step: 632
# episode: 10829   score: 14.0   step: 571
# episode: 10830   score: 20.0   step: 710

# %%
global episode
episode = 0
EPISODES = 8000000
env_name = "BreakoutDeterministic-v4"

# %%
class TestAgent:
    def __init__(self, action_size):
        self.state_size = (84, 84, 4)
        self.action_size = action_size

        self.discount_factor = 0.99
        self.no_op_steps = 30

        self.actor, self.critic = self.build_model()

    def build_model(self):
        input = Input(shape=self.state_size)
        conv = Conv2D(16, (8, 8), strides=(4, 4), activation='relu')(input)
        conv = Conv2D(32, (4, 4), strides=(2, 2), activation='relu')(conv)
        conv = Flatten()(conv)
        fc = Dense(256, activation='relu')(conv)
        policy = Dense(self.action_size, activation='softmax')(fc)
        value = Dense(1, activation='linear')(fc)

        actor = Model(inputs=input, outputs=policy)
        critic = Model(inputs=input, outputs=value)

        actor.summary()
        critic.summary()

        return actor, critic

    def get_action(self, history):
        history = np.float32(history / 255.)
        policy = self.actor.predict(history)[0]

        action_index = np.argmax(policy)
        return action_index

    def load_model(self, name):
        self.actor.load_weights(name)

# %%
model_to_load
# Out:
# 'model_trained.h5'

# %%
if __name__ == "__main__":
    env = gym.make(env_name)
    agent = TestAgent(action_size=3)
    agent.load_model("save_model/breakout_a3c_5_actor.h5")

    step = 0

    while episode < EPISODES:
        done = False
        dead = False

        score, start_life = 0, 5
        observe = env.reset()
        next_observe = observe

        for _ in range(random.randint(1, 20)):
            observe = next_observe
            next_observe, _, _, _ = env.step(1)

        state = pre_processing(next_observe, observe)
        history = np.stack((state, state, state, state), axis=2)
        history = np.reshape([history], (1, 84, 84, 4))

        while not done:
            env.render()
            step += 1
            observe = next_observe

            action = agent.get_action(history)

            if action == 1:
                fake_action = 2
            elif action == 2:
                fake_action = 3
            else:
                fake_action = 1

            if dead:
                fake_action = 1
                dead = False

            next_observe, reward, done, info = env.step(fake_action)

            next_state = pre_processing(next_observe, observe)
            next_state = np.reshape([next_state], (1, 84, 84, 1))
            next_history = np.append(next_state, history[:, :, :, :3], axis=3)

            if start_life > info['ale.lives']:
                dead = True
                reward = -1
                start_life = info['ale.lives']

            score += reward

            # if agent is dead, then reset the history
            if dead:
                history = np.stack(
                    (next_state, next_state, next_state, next_state), axis=2)
                history = np.reshape([history], (1, 84, 84, 4))
            else:
                history = next_history

            # if done, plot the score over episodes
            if done:
                episode += 1
                print("episode:", episode, "  score:", score, "  step:", step)
                step = 0
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 20, 20, 32)        8224
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 9, 9, 64)          32832
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 1,685,667
# Trainable params: 1,685,667
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py:1735: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# episode: 0   score: 0.0
# episode: 1   score: 0.0
# episode: 2   score: 0.0
# episode: 3   score: 2.0
# episode: 4   score: 0.0
# episode: 5   score: 0.0
# episode: 6   score: 2.0
# episode: 7   score: 0.0
# episode: 8   score: 1.0
# episode: 9   score: 0.0

# %%
# !ls /tmp/BreakoutDeterministic-v4 -al
# Out:
# total 48
# drwxr-xr-x 2 root root 4096 Oct  7 06:59 .
# drwxrwxrwt 1 root root 4096 Oct  7 06:59 ..
# -rw-r--r-- 1 root root 1969 Oct  7 06:59 openaigym.video.2.123.video000000.meta.json
# -rw-r--r-- 1 root root 7844 Oct  7 06:59 openaigym.video.2.123.video000000.mp4
# -rw-r--r-- 1 root root 1969 Oct  7 06:59 openaigym.video.2.123.video000001.meta.json
# -rw-r--r-- 1 root root 7844 Oct  7 06:59 openaigym.video.2.123.video000001.mp4
# -rw-r--r-- 1 root root 1969 Oct  7 06:59 openaigym.video.2.123.video000008.meta.json
# -rw-r--r-- 1 root root 9075 Oct  7 06:59 openaigym.video.2.123.video000008.mp4

# %%
ipython_show_video("/tmp/BreakoutDeterministic-v4/openaigym.video.2.123.video000008.mp4")
# Out:
#         <video alt="test" controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4" />
#         </video>
